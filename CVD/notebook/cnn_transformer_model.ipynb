# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Input, LayerNormalization
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#dataset loading
df = pd.read_csv("C:/Users/avish/Desktop/Sem 8/Final Project/Heart_Disease_Prediction/CVD/data/heart.csv")

# %%
# Rename columns (from your previous code)
df = df.rename(
    columns={
        'cp': 'chest_pain_type',
        'trestbps': 'resting_blood_pressure',
        'chol': 'cholesterol',
        'fbs': 'fasting_blood_sugar',
        'restecg': 'resting_electrocardiogram',
        'thalach': 'max_heart_rate_achieved',
        'exang': 'exercise_induced_angina',
        'oldpeak': 'st_depression',
        'slope': 'st_slope',
        'ca': 'num_major_vessels',
        'thal': 'thalassemia'
    }
)

# %%
# dropping the wrong ca vlaues and error values from thal
df = df[df['num_major_vessels']<4]
df = df[df['thalassemia']>0]
print(f'The length of the data row now is {len(df)} instead of 1025')
# Out:
# The length of the data row now is 1000 instead of 1025

# %%
# Define features and target
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# Check class distribution before SMOTE
print("Class distribution before SMOTE:", pd.Series(y).value_counts().to_dict())
# Out:
# Class distribution before SMOTE: {1: 508, 0: 492}

# %%
# Apply SMOTE to balance classes
oversample = SMOTE(random_state=42)
X, y = oversample.fit_resample(X, y)

# Check class distribution after SMOTE
print("Class distribution after SMOTE:", pd.Series(y).value_counts().to_dict())
# Out:
# Class distribution after SMOTE: {0: 508, 1: 508}

# %%
# Split into train (80%), validation (10%), test (10%)
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.1111, random_state=42)

# %%
# Scale features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %%
import pickle
with open('models/scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
# Reshape for deep learning (CNN and Transformer expect 3D input: samples, features, 1)
X_train_dl = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_val_dl = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
X_test_dl = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Print shapes
print("X_train shape:", X_train.shape, "X_train_dl shape:", X_train_dl.shape)
print("X_val shape:", X_val.shape, "X_val_dl shape:", X_val_dl.shape)
print("X_test shape:", X_test.shape, "X_test_dl shape:", X_test_dl.shape)
print("y_train shape:", y_train.shape, "y_val shape:", y_val.shape, "y_test shape:", y_test.shape)
# Out:
# X_train shape: (812, 13) X_train_dl shape: (812, 13, 1)
# X_val shape: (102, 13) X_val_dl shape: (102, 13, 1)
# X_test shape: (102, 13) X_test_dl shape: (102, 13, 1)
# y_train shape: (812,) y_val shape: (102,) y_test shape: (102,)

# %%
# Define CNN model
cnn_model = Sequential([
    Conv1D(32, kernel_size=3, activation='relu', padding='same', input_shape=(13, 1)),
    MaxPooling1D(pool_size=2),
    Conv1D(64, kernel_size=3, activation='relu', padding='same'),
    MaxPooling1D(pool_size=2),
    Dropout(0.4),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

# Compile model
cnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Train model
cnn_history = cnn_model.fit(
    X_train_dl, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val_dl, y_val),
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5651 - loss: 0.6718 - val_accuracy: 0.7451 - val_loss: 0.5858
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7735 - loss: 0.5495 - val_accuracy: 0.7451 - val_loss: 0.5059
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8085 - loss: 0.4432 - val_accuracy: 0.8137 - val_loss: 0.4536
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8204 - loss: 0.3831 - val_accuracy: 0.8431 - val_loss: 0.4435
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8557 - loss: 0.3561 - val_accuracy: 0.8333 - val_loss: 0.4431
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8614 - loss: 0.3307 - val_accuracy: 0.8333 - val_loss: 0.4153
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8688 - loss: 0.3245 - val_accuracy: 0.8431 - val_loss: 0.4105
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8551 - loss: 0.3880 - val_accuracy: 0.8235 - val_loss: 0.4178
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8477 - loss: 0.3493 - val_accuracy: 0.8529 - val_loss: 0.3912
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8668 - loss: 0.3046 - val_accuracy: 0.8431 - val_loss: 0.3868
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8784 - loss: 0.3186 - val_accuracy: 0.8431 - val_loss: 0.3825
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8826 - loss: 0.2890 - val_accuracy: 0.8431 - val_loss: 0.3848
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9044 - loss: 0.2663 - val_accuracy: 0.8431 - val_loss: 0.3702
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9050 - loss: 0.2644 - val_accuracy: 0.8627 - val_loss: 0.3528
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8789 - loss: 0.3238 - val_accuracy: 0.8529 - val_loss: 0.3591
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8944 - loss: 0.3056 - val_accuracy: 0.8725 - val_loss: 0.3436
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9108 - loss: 0.2172 - val_accuracy: 0.8627 - val_loss: 0.3580
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8966 - loss: 0.2525 - val_accuracy: 0.8627 - val_loss: 0.3356
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9145 - loss: 0.2400 - val_accuracy: 0.8529 - val_loss: 0.3430
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9135 - loss: 0.2435 - val_accuracy: 0.8627 - val_loss: 0.3150
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9103 - loss: 0.2365 - val_accuracy: 0.8824 - val_loss: 0.2958
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9100 - loss: 0.2046 - val_accuracy: 0.9216 - val_loss: 0.2944
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9122 - loss: 0.2346 - val_accuracy: 0.8922 - val_loss: 0.2804
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9409 - loss: 0.1792 - val_accuracy: 0.9118 - val_loss: 0.2758
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9269 - loss: 0.1894 - val_accuracy: 0.9118 - val_loss: 0.2704
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9364 - loss: 0.1694 - val_accuracy: 0.8922 - val_loss: 0.2581
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9192 - loss: 0.2074 - val_accuracy: 0.9314 - val_loss: 0.2430
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9279 - loss: 0.1750 - val_accuracy: 0.9216 - val_loss: 0.2420
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9346 - loss: 0.1803 - val_accuracy: 0.9020 - val_loss: 0.2366
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9499 - loss: 0.1489 - val_accuracy: 0.8922 - val_loss: 0.2560
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9328 - loss: 0.1601 - val_accuracy: 0.9314 - val_loss: 0.2135
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9426 - loss: 0.1568 - val_accuracy: 0.9412 - val_loss: 0.2056
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9417 - loss: 0.1501 - val_accuracy: 0.9020 - val_loss: 0.2032
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9433 - loss: 0.1449 - val_accuracy: 0.9412 - val_loss: 0.2033
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9400 - loss: 0.1406 - val_accuracy: 0.9314 - val_loss: 0.1950
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9482 - loss: 0.1440 - val_accuracy: 0.9412 - val_loss: 0.1956
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9603 - loss: 0.1387 - val_accuracy: 0.9216 - val_loss: 0.1866
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9584 - loss: 0.1177 - val_accuracy: 0.9412 - val_loss: 0.1960
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9561 - loss: 0.1241 - val_accuracy: 0.9118 - val_loss: 0.1764
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9502 - loss: 0.1336 - val_accuracy: 0.9412 - val_loss: 0.1718
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9533 - loss: 0.1173 - val_accuracy: 0.9412 - val_loss: 0.1569
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9484 - loss: 0.1209 - val_accuracy: 0.9412 - val_loss: 0.1593
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9705 - loss: 0.1058 - val_accuracy: 0.9608 - val_loss: 0.1565
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9657 - loss: 0.0964 - val_accuracy: 0.9706 - val_loss: 0.1512
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9597 - loss: 0.1133 - val_accuracy: 0.9608 - val_loss: 0.1522
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9573 - loss: 0.1063 - val_accuracy: 0.9412 - val_loss: 0.1371
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9607 - loss: 0.1022 - val_accuracy: 0.9412 - val_loss: 0.1327
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9643 - loss: 0.0911 - val_accuracy: 0.9412 - val_loss: 0.1431
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9633 - loss: 0.1001 - val_accuracy: 0.9510 - val_loss: 0.1360
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9693 - loss: 0.0822 - val_accuracy: 0.9412 - val_loss: 0.1579

# %%
# Evaluate on test set
cnn_test_pred_proba = cnn_model.predict(X_test_dl).flatten()
cnn_test_pred = (cnn_test_pred_proba > 0.5).astype(int)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
# Metrics
cnn_test_loss, cnn_test_accuracy = cnn_model.evaluate(X_test_dl, y_test, verbose=0)
cnn_test_pred_proba = cnn_model.predict(X_test_dl).flatten()
cnn_test_pred = (cnn_test_pred_proba > 0.5).astype(int)
cnn_accuracy = accuracy_score(y_test, cnn_test_pred)
cnn_report = classification_report(y_test, cnn_test_pred, output_dict=True)
cnn_cm = confusion_matrix(y_test, cnn_test_pred)
cnn_fpr, cnn_tpr, _ = roc_curve(y_test, cnn_test_pred_proba)
cnn_roc_auc = auc(cnn_fpr, cnn_tpr)

print("CNN Test Performance Metrics:")
print(f"Test Loss: {cnn_test_loss:.4f}")
print(f"Test Accuracy: {cnn_test_accuracy*100:.2f}%")
print(f"Accuracy (sklearn): {cnn_accuracy*100:.2f}%")
print(f"ROC-AUC: {cnn_roc_auc:.2f}")
print(f"Recall: {cnn_report['1']['recall']:.2f}")
print(f"Precision: {cnn_report['1']['precision']:.2f}")
print(f"F1-Score: {cnn_report['1']['f1-score']:.2f}")
print("Confusion Matrix:\n", cnn_cm)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# CNN Test Performance Metrics:
# Test Loss: 0.1165
# Test Accuracy: 96.08%
# Accuracy (sklearn): 96.08%
# ROC-AUC: 0.99
# Recall: 0.93
# Precision: 1.00
# F1-Score: 0.97
# Confusion Matrix:
#  [[41  0]
#  [ 4 57]]

# %%
# Check for underfitting/overfitting
train_loss_final = cnn_history.history['loss'][-1]
val_loss_final = cnn_history.history['val_loss'][-1]
train_acc_final = cnn_history.history['accuracy'][-1]
val_acc_final = cnn_history.history['val_accuracy'][-1]

print("\nCNN Underfitting/Overfitting Analysis:")
print(f"Final Training Loss: {train_loss_final:.4f}, Validation Loss: {val_loss_final:.4f}")
print(f"Final Training Accuracy: {train_acc_final*100:.2f}%, Validation Accuracy: {val_acc_final*100:.2f}%")
if train_loss_final > val_loss_final + 0.1 or train_acc_final < 0.7:
    print("Possible Underfitting: Training loss is high or accuracy is low.")
elif val_loss_final > train_loss_final + 0.1 and val_acc_final < train_acc_final - 0.1:
    print("Possible Overfitting: Validation loss/accuracy significantly worse than training.")
else:
    print("Good Fit: Training and validation metrics are close.")
# Out:
# CNN Underfitting/Overfitting Analysis:
# Final Training Loss: 0.0851, Validation Loss: 0.1579
# Final Training Accuracy: 96.92%, Validation Accuracy: 94.12%
# Good Fit: Training and validation metrics are close.

# %%
# Plot accuracy and loss
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
ax1.plot(cnn_history.history['accuracy'], label='Train Accuracy')
ax1.plot(cnn_history.history['val_accuracy'], label='Val Accuracy')
ax1.set_title('CNN Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax1.grid(True)

ax2.plot(cnn_history.history['loss'], label='Train Loss')
ax2.plot(cnn_history.history['val_loss'], label='Val Loss')
ax2.set_title('CNN Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()
ax2.grid(True)
plt.tight_layout()
plt.show()

# %%
# save cnn model
cnn_model.save("models/computer_cnn_model.keras")
print("Model saved!")

# %% [markdown]
# Transformer Model

# %%
# # Transformer Model
# class MultiHeadSelfAttention(tf.keras.layers.Layer):
#     def __init__(self, embed_dim, num_heads):
#         super(MultiHeadSelfAttention, self).__init__()
#         self.embed_dim = embed_dim
#         self.num_heads = num_heads
#         assert embed_dim % num_heads == 0
#         self.projection_dim = embed_dim // num_heads
#         self.query_dense = Dense(embed_dim)
#         self.key_dense = Dense(embed_dim)
#         self.value_dense = Dense(embed_dim)
#         self.combine_heads = Dense(embed_dim)

#     def attention(self, query, key, value):
#         score = tf.matmul(query, key, transpose_b=True)
#         dim_key = tf.cast(tf.shape(key)[-1], tf.float32)
#         scaled_score = score / tf.math.sqrt(dim_key)
#         weights = tf.nn.softmax(scaled_score, axis=-1)
#         output = tf.matmul(weights, value)
#         return output, weights

#     def separate_heads(self, x, batch_size):
#         x = tf.reshape(x, (batch_size, -1, self.num_heads, self.projection_dim))
#         return tf.transpose(x, perm=[0, 2, 1, 3])

#     def call(self, inputs, training=None):
#         batch_size = tf.shape(inputs)[0]
#         query = self.query_dense(inputs)
#         key = self.key_dense(inputs)
#         value = self.value_dense(inputs)
#         query = self.separate_heads(query, batch_size)
#         key = self.separate_heads(key, batch_size)
#         value = self.separate_heads(value, batch_size)
#         attention, weights = self.attention(query, key, value)
#         attention = tf.transpose(attention, perm=[0, 2, 1, 3])
#         concat_attention = tf.reshape(attention, (batch_size, -1, self.embed_dim))
#         output = self.combine_heads(concat_attention)
#         return output

# class TransformerBlock(tf.keras.layers.Layer):
#     def __init__(self, embed_dim, num_heads, ff_dim, rate=0.2):
#         super(TransformerBlock, self).__init__()
#         self.att = MultiHeadSelfAttention(embed_dim, num_heads)
#         self.ffn = Sequential([Dense(ff_dim, activation='relu'), Dense(embed_dim)])
#         self.layernorm1 = LayerNormalization(epsilon=1e-6)
#         self.layernorm2 = LayerNormalization(epsilon=1e-6)
#         self.dropout1 = Dropout(rate)
#         self.dropout2 = Dropout(rate)

#     def call(self, inputs, training=None):
#         attn_output = self.att(inputs, training=training)
#         attn_output = self.dropout1(attn_output, training=training)
#         out1 = self.layernorm1(inputs + attn_output)
#         ffn_output = self.ffn(out1)
#         ffn_output = self.dropout2(ffn_output, training=training)
#         return self.layernorm2(out1 + ffn_output)

# def build_transformer(input_shape, embed_dim=64, num_heads=4, ff_dim=128):
#     inputs = Input(shape=(input_shape, 1))
#     x = Dense(embed_dim)(inputs)
#     x = TransformerBlock(embed_dim, num_heads, ff_dim)(x)
#     x = TransformerBlock(embed_dim, num_heads, ff_dim)(x)
#     x = tf.keras.layers.GlobalAveragePooling1D()(x)
#     x = Dense(64, activation='relu')(x)
#     x = Dropout(0.2)(x)
#     outputs = Dense(1, activation='sigmoid')(x)
#     model = Model(inputs=inputs, outputs=outputs)
#     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), 
#                   loss='binary_crossentropy', 
#                   metrics=['accuracy'])
#     return model

# %%
# # Instantiate and train the model
# transformer_model = build_transformer(13)
# transformer_history = transformer_model.fit(
#     X_train_dl, y_train,
#     epochs=100,
#     batch_size=32,
#     validation_data=(X_val_dl, y_val),
#     callbacks=[EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)],
#     verbose=1
# )

# %%
# transformer_test_loss, transformer_test_accuracy = transformer_model.evaluate(X_test_dl, y_test, verbose=0)
# transformer_test_pred_proba = transformer_model.predict(X_test_dl).flatten()
# threshold = 0.3
# transformer_test_pred = (transformer_test_pred_proba > threshold).astype(int)
# print("Transformer Test Performance Metrics (Threshold=0.3):")

# transformer_accuracy = accuracy_score(y_test, transformer_test_pred)
# transformer_report = classification_report(y_test, transformer_test_pred, output_dict=True)
# transformer_cm = confusion_matrix(y_test, transformer_test_pred)
# transformer_fpr, transformer_tpr, _ = roc_curve(y_test, transformer_test_pred_proba)
# transformer_roc_auc = auc(transformer_fpr, transformer_tpr)
# print(f"Test Loss: {transformer_test_loss:.4f}")
# print(f"Test Accuracy: {transformer_test_accuracy*100:.2f}%")
# print(f"Accuracy (sklearn, threshold=0.3): {transformer_accuracy*100:.2f}%")
# print(f"ROC-AUC: {transformer_roc_auc:.2f}")
# print(f"Recall: {transformer_report['1']['recall']:.2f}")
# print(f"Precision: {transformer_report['1']['precision']:.2f}")
# print(f"F1-Score: {transformer_report['1']['f1-score']:.2f}")
# print("Confusion Matrix:\n", transformer_cm)

# %%
# # Check for underfitting/overfitting
# train_loss_final = transformer_history.history['loss'][-1]
# val_loss_final = transformer_history.history['val_loss'][-1]
# train_acc_final = transformer_history.history['accuracy'][-1]
# val_acc_final = transformer_history.history['val_accuracy'][-1]

# print("\nTransformer Underfitting/Overfitting Analysis:")
# print(f"Final Training Loss: {train_loss_final:.4f}, Validation Loss: {val_loss_final:.4f}")
# print(f"Final Training Accuracy: {train_acc_final*100:.2f}%, Validation Accuracy: {val_acc_final*100:.2f}%")
# if train_loss_final > val_loss_final + 0.1 or train_acc_final < 0.7:
#     print("Possible Underfitting: Training loss is high or accuracy is low.")
# elif val_loss_final > train_loss_final + 0.1 and val_acc_final < train_acc_final - 0.1:
#     print("Possible Overfitting: Validation loss/accuracy significantly worse than training.")
# else:
#     print("Good Fit: Training and validation metrics are close.")

# %%
# # Plot accuracy and loss
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
# ax1.plot(transformer_history.history['accuracy'], label='Train Accuracy')
# ax1.plot(transformer_history.history['val_accuracy'], label='Val Accuracy')
# ax1.set_title('Transformer Accuracy')
# ax1.set_xlabel('Epoch')
# ax1.set_ylabel('Accuracy')
# ax1.legend()
# ax1.grid(True)

# ax2.plot(transformer_history.history['loss'], label='Train Loss')
# ax2.plot(transformer_history.history['val_loss'], label='Val Loss')
# ax2.set_title('Transformer Loss')
# ax2.set_xlabel('Epoch')
# ax2.set_ylabel('Loss')
# ax2.legend()
# ax2.grid(True)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# GELU

# %%
# Positional Encoding Layer
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, max_len, embed_dim):
        super(PositionalEncoding, self).__init__()
        self.max_len = max_len
        self.embed_dim = embed_dim
        self.pos_encoding = self.positional_encoding(max_len, embed_dim)

    def positional_encoding(self, max_len, embed_dim):
        pos = np.arange(max_len)[:, np.newaxis]
        i = np.arange(embed_dim)[np.newaxis, :]
        angle_rads = pos / np.power(10000, (2 * (i // 2)) / np.float32(embed_dim))
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        pos_encoding = angle_rads[np.newaxis, ...]
        return tf.cast(pos_encoding, dtype=tf.float32)

    def call(self, inputs):
        return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]

# Multi-Head Self-Attention Layer
class MultiHeadSelfAttention(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads):
        super(MultiHeadSelfAttention, self).__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        assert embed_dim % num_heads == 0
        self.projection_dim = embed_dim // num_heads
        self.query_dense = Dense(embed_dim)
        self.key_dense = Dense(embed_dim)
        self.value_dense = Dense(embed_dim)
        self.combine_heads = Dense(embed_dim)

    def attention(self, query, key, value):
        score = tf.matmul(query, key, transpose_b=True)
        dim_key = tf.cast(tf.shape(key)[-1], tf.float32)
        scaled_score = score / tf.math.sqrt(dim_key)
        weights = tf.nn.softmax(scaled_score, axis=-1)
        output = tf.matmul(weights, value)
        return output, weights

    def separate_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.projection_dim))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, inputs, training=None):
        batch_size = tf.shape(inputs)[0]
        query = self.query_dense(inputs)
        key = self.key_dense(inputs)
        value = self.value_dense(inputs)
        query = self.separate_heads(query, batch_size)
        key = self.separate_heads(key, batch_size)
        value = self.separate_heads(value, batch_size)
        attention, weights = self.attention(query, key, value)
        attention = tf.transpose(attention, perm=[0, 2, 1, 3])
        concat_attention = tf.reshape(attention, (batch_size, -1, self.embed_dim))
        output = self.combine_heads(concat_attention)
        return output

# Transformer Block with GELU
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.2):
        super(TransformerBlock, self).__init__()
        self.att = MultiHeadSelfAttention(embed_dim, num_heads)
        self.ffn = tf.keras.Sequential([
            Dense(ff_dim, activation='gelu'),  # Changed to GELU
            Dense(embed_dim)
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, inputs, training=None):
        attn_output = self.att(inputs, training=training)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# Build Transformer Model
def build_transformer(input_shape, embed_dim=128, num_heads=8, ff_dim=256):
    inputs = Input(shape=(input_shape, 1))
    x = Dense(embed_dim)(inputs)
    x = PositionalEncoding(max_len=input_shape, embed_dim=embed_dim)(x)  # Add Positional Encoding
    x = TransformerBlock(embed_dim, num_heads, ff_dim)(x)
    x = TransformerBlock(embed_dim, num_heads, ff_dim)(x)
    x = tf.keras.layers.GlobalAveragePooling1D()(x)
    x = Dense(128, activation='gelu')(x)  # Changed to GELU
    x = Dropout(0.3)(x)
    outputs = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
# Instantiate and train the model
transformer_model = build_transformer(13)
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
transformer_history = transformer_model.fit(
    X_train_dl, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val_dl, y_val),
    callbacks=[early_stop],
    verbose=1
)
# Out:
# WARNING:tensorflow:From C:\Users\avish\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\core.py:219: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.5840 - loss: 0.6926 - val_accuracy: 0.6176 - val_loss: 0.6562
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5766 - loss: 0.6741 - val_accuracy: 0.6863 - val_loss: 0.6158
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6718 - loss: 0.6214 - val_accuracy: 0.6667 - val_loss: 0.5820
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6448 - loss: 0.6341 - val_accuracy: 0.7549 - val_loss: 0.5467
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7338 - loss: 0.5615 - val_accuracy: 0.7647 - val_loss: 0.5389
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7396 - loss: 0.5734 - val_accuracy: 0.7745 - val_loss: 0.5181
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7567 - loss: 0.5273 - val_accuracy: 0.7745 - val_loss: 0.5068
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7974 - loss: 0.4856 - val_accuracy: 0.7745 - val_loss: 0.5059
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7805 - loss: 0.5093 - val_accuracy: 0.7745 - val_loss: 0.5031
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8078 - loss: 0.4568 - val_accuracy: 0.7745 - val_loss: 0.4772
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7982 - loss: 0.4486 - val_accuracy: 0.7451 - val_loss: 0.4707
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7810 - loss: 0.4877 - val_accuracy: 0.7745 - val_loss: 0.4694
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7979 - loss: 0.4412 - val_accuracy: 0.7745 - val_loss: 0.4632
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8054 - loss: 0.4376 - val_accuracy: 0.7745 - val_loss: 0.4649
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7939 - loss: 0.4298 - val_accuracy: 0.7745 - val_loss: 0.4386
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7902 - loss: 0.4112 - val_accuracy: 0.7745 - val_loss: 0.4281
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8150 - loss: 0.3907 - val_accuracy: 0.7745 - val_loss: 0.4540
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8235 - loss: 0.4062 - val_accuracy: 0.7941 - val_loss: 0.4268
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8339 - loss: 0.3472 - val_accuracy: 0.7745 - val_loss: 0.4764
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8365 - loss: 0.3695 - val_accuracy: 0.7843 - val_loss: 0.4627
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8503 - loss: 0.3336 - val_accuracy: 0.7941 - val_loss: 0.4098
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8393 - loss: 0.3787 - val_accuracy: 0.8137 - val_loss: 0.4173
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8097 - loss: 0.3922 - val_accuracy: 0.7843 - val_loss: 0.4180
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8423 - loss: 0.3361 - val_accuracy: 0.8039 - val_loss: 0.4323
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8347 - loss: 0.3654 - val_accuracy: 0.7745 - val_loss: 0.4301
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8569 - loss: 0.3390 - val_accuracy: 0.8137 - val_loss: 0.4127
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8481 - loss: 0.3510 - val_accuracy: 0.8235 - val_loss: 0.4350
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8419 - loss: 0.3392 - val_accuracy: 0.8235 - val_loss: 0.4105
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8458 - loss: 0.3296 - val_accuracy: 0.8235 - val_loss: 0.4117
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8428 - loss: 0.3300 - val_accuracy: 0.8235 - val_loss: 0.4051
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8559 - loss: 0.3060 - val_accuracy: 0.8137 - val_loss: 0.4095
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8708 - loss: 0.2908 - val_accuracy: 0.8137 - val_loss: 0.4118
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8542 - loss: 0.3075 - val_accuracy: 0.8333 - val_loss: 0.4143
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8450 - loss: 0.3273 - val_accuracy: 0.8137 - val_loss: 0.4233
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8696 - loss: 0.2807 - val_accuracy: 0.8039 - val_loss: 0.4234
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8841 - loss: 0.2785 - val_accuracy: 0.8235 - val_loss: 0.4406
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8755 - loss: 0.2917 - val_accuracy: 0.8137 - val_loss: 0.3972
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8718 - loss: 0.2875 - val_accuracy: 0.8235 - val_loss: 0.4288
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8712 - loss: 0.2803 - val_accuracy: 0.8431 - val_loss: 0.4065
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8801 - loss: 0.2953 - val_accuracy: 0.8235 - val_loss: 0.4077
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9003 - loss: 0.2323 - val_accuracy: 0.8137 - val_loss: 0.4027
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9032 - loss: 0.2514 - val_accuracy: 0.8235 - val_loss: 0.4092
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9040 - loss: 0.2744 - val_accuracy: 0.8039 - val_loss: 0.4039
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9112 - loss: 0.2490 - val_accuracy: 0.8431 - val_loss: 0.3764
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9013 - loss: 0.2359 - val_accuracy: 0.8235 - val_loss: 0.4023
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9143 - loss: 0.2241 - val_accuracy: 0.8725 - val_loss: 0.3795
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9263 - loss: 0.2211 - val_accuracy: 0.8529 - val_loss: 0.3873
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9110 - loss: 0.2125 - val_accuracy: 0.8235 - val_loss: 0.3709
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9259 - loss: 0.1884 - val_accuracy: 0.8529 - val_loss: 0.3745
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9361 - loss: 0.1760 - val_accuracy: 0.8333 - val_loss: 0.3626
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9188 - loss: 0.1985 - val_accuracy: 0.8725 - val_loss: 0.3455
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9364 - loss: 0.1659 - val_accuracy: 0.8824 - val_loss: 0.3399
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9396 - loss: 0.1804 - val_accuracy: 0.8725 - val_loss: 0.3551
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9351 - loss: 0.1797 - val_accuracy: 0.8725 - val_loss: 0.3318
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9329 - loss: 0.1766 - val_accuracy: 0.8824 - val_loss: 0.3321
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9395 - loss: 0.1660 - val_accuracy: 0.8824 - val_loss: 0.3204
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9408 - loss: 0.1651 - val_accuracy: 0.8824 - val_loss: 0.3347
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9417 - loss: 0.1682 - val_accuracy: 0.8824 - val_loss: 0.3267
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9623 - loss: 0.1214 - val_accuracy: 0.8725 - val_loss: 0.3201
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9607 - loss: 0.1355 - val_accuracy: 0.8725 - val_loss: 0.3420
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9348 - loss: 0.1552 - val_accuracy: 0.8824 - val_loss: 0.3206
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9603 - loss: 0.1096 - val_accuracy: 0.9020 - val_loss: 0.2980
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9499 - loss: 0.1287 - val_accuracy: 0.8824 - val_loss: 0.3080
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9374 - loss: 0.1735 - val_accuracy: 0.8922 - val_loss: 0.3556
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9365 - loss: 0.2063 - val_accuracy: 0.8922 - val_loss: 0.3025
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9504 - loss: 0.1587 - val_accuracy: 0.8922 - val_loss: 0.2812
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9521 - loss: 0.1057 - val_accuracy: 0.9020 - val_loss: 0.2779
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9628 - loss: 0.1204 - val_accuracy: 0.9118 - val_loss: 0.2824
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9507 - loss: 0.1227 - val_accuracy: 0.9020 - val_loss: 0.2702
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9727 - loss: 0.0987 - val_accuracy: 0.9118 - val_loss: 0.2718
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9563 - loss: 0.1156 - val_accuracy: 0.9118 - val_loss: 0.2596
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9712 - loss: 0.0950 - val_accuracy: 0.9216 - val_loss: 0.2420
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9470 - loss: 0.1428 - val_accuracy: 0.9118 - val_loss: 0.2476
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9658 - loss: 0.0964 - val_accuracy: 0.9020 - val_loss: 0.2357
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9668 - loss: 0.0944 - val_accuracy: 0.9118 - val_loss: 0.2311
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9709 - loss: 0.1095 - val_accuracy: 0.8922 - val_loss: 0.2452
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9590 - loss: 0.1149 - val_accuracy: 0.9216 - val_loss: 0.2342
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9706 - loss: 0.0900 - val_accuracy: 0.9118 - val_loss: 0.2373
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9570 - loss: 0.1154 - val_accuracy: 0.9510 - val_loss: 0.1946
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9661 - loss: 0.1029 - val_accuracy: 0.9216 - val_loss: 0.2109
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9737 - loss: 0.0887 - val_accuracy: 0.9020 - val_loss: 0.2243
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9678 - loss: 0.0933 - val_accuracy: 0.9216 - val_loss: 0.1919
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9703 - loss: 0.0826 - val_accuracy: 0.9118 - val_loss: 0.2614
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9669 - loss: 0.0857 - val_accuracy: 0.9510 - val_loss: 0.1857
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9726 - loss: 0.0826 - val_accuracy: 0.9510 - val_loss: 0.1845
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9631 - loss: 0.0884 - val_accuracy: 0.9314 - val_loss: 0.2073
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9615 - loss: 0.0851 - val_accuracy: 0.9314 - val_loss: 0.1774
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9689 - loss: 0.0899 - val_accuracy: 0.9706 - val_loss: 0.1797
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9647 - loss: 0.1020 - val_accuracy: 0.9608 - val_loss: 0.1757
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9750 - loss: 0.0769 - val_accuracy: 0.9510 - val_loss: 0.1723
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9726 - loss: 0.0692 - val_accuracy: 0.9608 - val_loss: 0.1662
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9738 - loss: 0.0709 - val_accuracy: 0.9510 - val_loss: 0.1613
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9729 - loss: 0.0765 - val_accuracy: 0.9706 - val_loss: 0.1529
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9733 - loss: 0.0694 - val_accuracy: 0.9706 - val_loss: 0.1505
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9797 - loss: 0.0599 - val_accuracy: 0.9804 - val_loss: 0.1463
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9797 - loss: 0.0771 - val_accuracy: 0.9314 - val_loss: 0.1725
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9678 - loss: 0.0672 - val_accuracy: 0.9706 - val_loss: 0.1481
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9705 - loss: 0.0977 - val_accuracy: 0.9510 - val_loss: 0.1623
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9737 - loss: 0.0855 - val_accuracy: 0.9608 - val_loss: 0.1688
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9738 - loss: 0.0805 - val_accuracy: 0.9510 - val_loss: 0.1626

# %%
# Evaluate on test set
transformer_test_loss, transformer_test_accuracy = transformer_model.evaluate(X_test_dl, y_test, verbose=0)
transformer_test_pred_proba = transformer_model.predict(X_test_dl).flatten()
transformer_test_pred = (transformer_test_pred_proba > 0.3).astype(int)

# Metrics
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
transformer_accuracy = accuracy_score(y_test, transformer_test_pred)
transformer_report = classification_report(y_test, transformer_test_pred, output_dict=True)
transformer_cm = confusion_matrix(y_test, transformer_test_pred)
transformer_fpr, transformer_tpr, _ = roc_curve(y_test, transformer_test_pred_proba)
transformer_roc_auc = auc(transformer_fpr, transformer_tpr)

print("Transformer Test Performance Metrics (Threshold=0.3):")
print(f"Test Loss: {transformer_test_loss:.4f}")
print(f"Test Accuracy: {transformer_test_accuracy*100:.2f}%")
print(f"Accuracy (sklearn, threshold=0.3): {transformer_accuracy*100:.2f}%")
print(f"ROC-AUC: {transformer_roc_auc:.2f}")
print(f"Recall: {transformer_report['1']['recall']:.2f}")
print(f"Precision: {transformer_report['1']['precision']:.2f}")
print(f"F1-Score: {transformer_report['1']['f1-score']:.2f}")
print("Confusion Matrix:\n", transformer_cm)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Transformer Test Performance Metrics (Threshold=0.3):
# Test Loss: 0.1309
# Test Accuracy: 98.04%
# Accuracy (sklearn, threshold=0.3): 98.04%
# ROC-AUC: 0.99
# Recall: 0.98
# Precision: 0.98
# F1-Score: 0.98
# Confusion Matrix:
#  [[40  1]
#  [ 1 60]]

# %%
# Check for underfitting/overfitting
train_loss_final = transformer_history.history['loss'][-1]
val_loss_final = transformer_history.history['val_loss'][-1]
train_acc_final = transformer_history.history['accuracy'][-1]
val_acc_final = transformer_history.history['val_accuracy'][-1]

print("\nTransformer Underfitting/Overfitting Analysis:")
print(f"Final Training Loss: {train_loss_final:.4f}, Validation Loss: {val_loss_final:.4f}")
print(f"Final Training Accuracy: {train_acc_final*100:.2f}%, Validation Accuracy: {val_acc_final*100:.2f}%")
if train_loss_final > val_loss_final + 0.1 or train_acc_final < 0.7:
    print("Possible Underfitting: Training loss is high or accuracy is low.")
elif val_loss_final > train_loss_final + 0.1 and val_acc_final < train_acc_final - 0.1:
    print("Possible Overfitting: Validation loss/accuracy significantly worse than training.")
else:
    print("Good Fit: Training and validation metrics are close.")
# Out:
# Transformer Underfitting/Overfitting Analysis:
# Final Training Loss: 0.0659, Validation Loss: 0.1626
# Final Training Accuracy: 97.91%, Validation Accuracy: 95.10%
# Good Fit: Training and validation metrics are close.

# %%
# Plot accuracy and loss
import matplotlib.pyplot as plt
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
ax1.plot(transformer_history.history['accuracy'], label='Train Accuracy')
ax1.plot(transformer_history.history['val_accuracy'], label='Val Accuracy')
ax1.set_title('Transformer Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax1.grid(True)

ax2.plot(transformer_history.history['loss'], label='Train Loss')
ax2.plot(transformer_history.history['val_loss'], label='Val Loss')
ax2.set_title('Transformer Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()
ax2.grid(True)
plt.tight_layout()
plt.show()

# %%
# save transformer model
cnn_model.save("models/computer_transformer_model.keras")
print("Model saved!")
# Out:
# Model saved!

# %% [markdown]
# CNN Hyperparameter Tuning

# %%
# # Done in kaggle and downloaded 
# import keras_tuner as kt
# def build_cnn_tuner(hp):
#     model = Sequential([
#         Conv1D(
#             filters=hp.Int('filters1', 16, 64, step=16),
#             kernel_size=3,
#             activation='relu',
#             padding='same',
#             input_shape=(13, 1)
#         ),
#         MaxPooling1D(pool_size=2),
#         Conv1D(
#             filters=hp.Int('filters2', 32, 128, step=32),
#             kernel_size=3,
#             activation='relu',
#             padding='same'
#         ),
#         MaxPooling1D(pool_size=2),
#         Dropout(hp.Float('dropout1', 0.2, 0.5, step=0.1)),
#         Flatten(),
#         Dense(hp.Int('dense_units', 32, 128, step=32), activation='relu'),
#         Dropout(hp.Float('dropout2', 0.2, 0.5, step=0.1)),
#         Dense(1, activation='sigmoid')
#     ])
#     model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#     return model

# tuner = kt.Hyperband(
#     build_cnn_tuner,
#     objective='val_accuracy',
#     max_epochs=50,
#     factor=3,
#     directory='cnn_tuner',
#     project_name='heart_disease'
# )
# tuner.search(
#     X_train_dl, y_train,
#     epochs=50,
#     validation_data=(X_val_dl, y_val),
#     callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)]
# )
# best_cnn_model = tuner.get_best_models(num_models=1)[0]

# # Evaluate best CNN model
# best_cnn_test_loss, best_cnn_test_accuracy = best_cnn_model.evaluate(X_test_dl, y_test, verbose=0)
# print(f"Best CNN Test Accuracy: {best_cnn_test_accuracy*100:.2f}%")

# %% [markdown]
# Transformer Hyperparameter Tuning

# %%
# Done in kaggle and downloaded 
# def build_transformer_tuner(hp):
#     embed_dim = hp.Int('embed_dim', 32, 128, step=32)
#     num_heads = hp.Int('num_heads', 2, 8, step=2)
#     ff_dim = hp.Int('ff_dim', 64, 256, step=64)
#     learning_rate = hp.Float('learning_rate', 1e-5, 1e-3, sampling='log')
    
#     inputs = Input(shape=(13, 1))
#     x = Dense(embed_dim)(inputs)
#     x = PositionalEncoding(max_len=13, embed_dim=embed_dim)(x)
#     x = TransformerBlock(embed_dim, num_heads, ff_dim)(x)
#     x = TransformerBlock(embed_dim, num_heads, ff_dim)(x)
#     x = tf.keras.layers.GlobalAveragePooling1D()(x)
#     x = Dense(128, activation='gelu')(x)
#     x = Dropout(0.3)(x)
#     outputs = Dense(1, activation='sigmoid')(x)
#     model = Model(inputs=inputs, outputs=outputs)
#     model.compile(
#         optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
#         loss='binary_crossentropy',
#         metrics=['accuracy']
#     )
#     return model

# tuner = kt.Hyperband(
#     build_transformer_tuner,
#     objective='val_accuracy',
#     max_epochs=50,
#     factor=3,
#     directory='transformer_tuner',
#     project_name='heart_disease'
# )
# tuner.search(
#     X_train_dl, y_train,
#     epochs=50,
#     validation_data=(X_val_dl, y_val),
#     callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)]
# )
# best_transformer_model = tuner.get_best_models(num_models=1)[0]

# # Evaluate best Transformer model
# best_transformer_test_loss, best_transformer_test_accuracy = best_transformer_model.evaluate(X_test_dl, y_test, verbose=0)
# print(f"Best Transformer Test Accuracy: {best_transformer_test_accuracy*100:.2f}%")

# %%
# from sklearn.model_selection import KFold
# # Updated build_transformer_tuner function
# def build_transformer_tuner(hp):
#     # Define embed_dim
#     embed_dim = hp.Int('embed_dim', 32, 256, step=32)
#     # **Changed**: Dynamically select num_heads to ensure divisibility by embed_dim
#     max_heads = min(16, embed_dim)  # Cap at 16 or embed_dim
#     valid_heads = [h for h in range(2, max_heads + 1, 2) if embed_dim % h == 0]
#     num_heads = hp.Choice('num_heads', valid_heads) if valid_heads else 2  # Fallback to 2 if no valid heads
#     ff_dim = hp.Int('ff_dim', 64, 512, step=64)
#     dropout_rate = hp.Float('dropout_rate', 0.1, 0.5, step=0.1)
#     num_blocks = hp.Int('num_blocks', 2, 4, step=1)
#     learning_rate = hp.Choice('learning_rate', [1e-5, 5e-5, 1e-4, 5e-4, 1e-3])
#     weight_decay = hp.Float('weight_decay', 1e-6, 1e-2, sampling='log')
#     pooling = hp.Choice('pooling', ['avg', 'max'])

#     inputs = tf.keras.layers.Input(shape=(13, 1))
#     x = tf.keras.layers.Dense(embed_dim)(inputs)
#     x = PositionalEncoding(max_len=13, embed_dim=embed_dim)(x)
#     for _ in range(num_blocks):
#         x = TransformerBlock(embed_dim, num_heads, ff_dim, rate=dropout_rate)(x)
#     if pooling == 'avg':
#         x = tf.keras.layers.GlobalAveragePooling1D()(x)
#     else:
#         x = tf.keras.layers.GlobalMaxPooling1D()(x)
#     x = tf.keras.layers.Dense(128, activation='gelu')(x)
#     x = tf.keras.layers.Dropout(dropout_rate)(x)
#     outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
#     model = tf.keras.Model(inputs=inputs, outputs=outputs)
#     model.compile(
#         optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate, weight_decay=weight_decay),
#         loss='binary_crossentropy',
#         metrics=['accuracy']
#     )
#     return model

# # Combine training and validation data for cross-validation
# X_full = np.concatenate([X_train_dl, X_val_dl], axis=0)
# y_full = np.concatenate([y_train, y_val], axis=0)

# # Create tuner
# tuner = kt.Hyperband(
#     build_transformer_tuner,
#     objective='val_accuracy',
#     max_epochs=50,
#     hyperband_iterations=3,
#     factor=3,
#     # **Changed**: Increased max_consecutive_failed_trials to tolerate potential failures
#     max_consecutive_failed_trials=10,
#     directory='transformer_tuner',
#     project_name='heart_disease_cv'
# )

# # Perform tuning with cross-validation
# kfold = KFold(n_splits=5, shuffle=True, random_state=42)
# for fold, (train_idx, val_idx) in enumerate(kfold.split(X_full, y_full)):
#     X_train_fold = X_full[train_idx]
#     y_train_fold = y_full[train_idx]
#     X_val_fold = X_full[val_idx]
#     y_val_fold = y_full[val_idx]
#     tuner.search(
#         X_train_fold, y_train_fold,
#         epochs=50,
#         validation_data=(X_val_fold, y_val_fold),
#         callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)]
#     )

# # Get the best model
# best_transformer_model = tuner.get_best_models(num_models=1)[0]

# # Evaluate on test set
# best_transformer_test_loss, best_transformer_test_accuracy = best_transformer_model.evaluate(X_test_dl, y_test, verbose=0)
# print(f"Best Transformer Test Accuracy: {best_transformer_test_accuracy*100:.2f}%")
